# %% [markdown]
# # Введение в gymnasium. Создание кастомной среды и обучение DQN-агента
#
# ---
# #### Сегодня мы:
# - Создадим кастомную среду в Gymnasium, аналогичную классической CartPole (обратный маятник)
# - Обучим агента с помощью Deep Q-Network (DQN)
# - Увидим, как гиперпараметры влияют на обучение модели

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Официальный гайд на создание кастомных сред в Gymnasium - https://gymnasium.farama.org/introduction/create_custom_env/

# %% [markdown]
# ## Устанавливаем необходимые библиотеки

# %%
# !pip install gymnasium
# !pip install pyvirtualdisplay # нужен для рендеринга в колабе
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)

# %% [markdown]
# Мы будем создавать среду, идентичную CartPole
#
# Структура проекта:
#
#
# ```
# dima@dima-TBk-14-G7-AHP:~/projects/RL_course_2$ tree
# .
# ├── gymnasium_env_RL_course
# │   ├── envs
# │   │   ├── cartpole_DQN_train.py
# │   │   ├── cartpole_env.py
# │   │   ├── __init__.py
# │   ├── __init__.py
# ├── pyproject.toml
# ├── run_DQN_cartpole.py
# ├── setup.py
#
# ```

# %% [markdown]
# Удаление всех предыдущих файлов (чтобы избегать ошибок при долгой работе с ноутбуком)

# %%
! rm -r /content/*
# Out:
# rm: cannot remove '/content/*': No such file or directory

# %% [markdown]
# ## Создание необходимых файлов (структуры проекта)
#
# Эти файлы делают проект устанавливаемым для `pip install -e .`

# %%
# !mkdir -p RL_course_2/gymnasium_env_RL_course/envs

# %% [markdown]
# `setup.py` и `pyproject.toml` — файлы конфигурации пакета. Они описывают, как установить пакет: какие зависимости нужны (`gymnasium`, `pygame`, `...`), имя пакета и т.д.

# %%
# %%writefile RL_course_2/setup.py

from setuptools import setup

setup(
    name='gymnasium_env_RL_course',
    version='0.1.0',
    packages=['envs'],
)
# Out:
# Overwriting RL_course_2/setup.py

# %%
# %%writefile RL_course_2/pyproject.toml
#
# [build-system]
# requires = ["hatchling"]
# build-backend = "hatchling.build"
#
# [tool.hatch.build.targets.wheel]
# packages = ["gymnasium_env_RL_course"]
#
# [project]
# name = "gymnasium_env_RL_course"
# version = "0.0.1"
# dependencies = [
#   "gymnasium",
#   "pygame>=2.1.3",
#   "pre-commit",
# ]
# Out:
# Writing RL_course_2/pyproject.toml

# %% [markdown]
# Создаем `__init__.py` файлы, которые позволяют воспринимать директорию как python-пакет:

# %%
# %%writefile RL_course_2/gymnasium_env_RL_course/envs/__init__.py

from gymnasium.envs.registration import register

register(
    id='gymnasium_env_RL_course/CartPoleEnv-v0',
    entry_point='gymnasium_env_RL_course.envs.cartpole_env:CartPoleEnv',
)
# Out:
# Writing RL_course_2/gymnasium_env_RL_course/envs/__init__.py

# %%
# %%writefile RL_course_2/gymnasium_env_RL_course/__init__.py
from gymnasium.envs.registration import register
from . import envs # импоритруем директорию со средой и первым __init__

register( # старая среда для примера
    id="gymnasium_env_RL_course/GridWorld-v0",
    entry_point="gymnasium_env_RL_course.envs:GridWorldEnv",
)
# Out:
# Writing RL_course_2/gymnasium_env_RL_course/__init__.py

# %% [markdown]
# ## Создание файла среды: cartpole_env.py

# %% [markdown]
# В скрипте ниже мы создаем среду CartPoleEnv.
# Она наследуется от gym.Env и определяет:
#
# ### Пространства действий/состояний:
#
# - **2 действия**:
#
# 1. Толкаем тележку влево
# 2. Толкаем вправо
#
# - **4 наблюдения**:
#
# 1. Позиция тележки
# 2. Угол палки
# 3. Скорость тележки
# 4. Скорость вращения палки
#
#
# ### Методы:
#
#     reset() — сбрасывает среду в исходное состояние
#
# Инициализирует среду перед началом нового эпизода.
# Возвращает:
# - начальное состояние среды (наблюдение)
# - вспомогательную информацию
#
# Пример: После сброса агент 'видит' тележку около центра и палку около вертикали, и эпизод начинается.
#
#
#     step() —  Здесь содержится основная логика.
#
# В этом месте агент посылает среде свое действие.
# Метод принимает действие, вычисляет состояние среды после применения этого действия и возвращает кортеж из:
# - нового состояния среды, награды
# - статуса (terminated, truncated - закончен ли эпизод)
# - вспомогательной информации
#
# Пример: Агент толкает вправо => тележка движется, палка перемещается новое состояние, награда +1, и флаг terminated=False.
#
#     render() — визуализация текущего состояния
#
# Никак не влияет на логику среды, только визуализирует.
# Этот метод имеет 2 режима:
# - human
#
#     отображает визуализацию в окне pygame / выводит в консоль положение тележки - выдача данных, предназначенных для человека
# - rgb_array
#
#     Возвращает массив пикселей с RGB значениями. Для программного использования.
#
# Пример: далее мы будем использовать `mode="human"` чтобы выводить данные в консоль и `mode="rgb_array"` чтобы сохранять массив с RGB для дальнейшей реконструкции GIF.

# %%
# %%writefile RL_course_2/gymnasium_env_RL_course/envs/cartpole_env.py

import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

class CartPoleEnv(gym.Env): # наследуем от базового класса Gymnasium
    """
    Кастомная среда CartPole (обратный маятник).
    Идентична CartPole-v1 (Gymnasium)
    """
    metadata = {"render_modes": ["human", "rgb_array"], 'render_fps': 30}

    def __init__(self, render_mode=None):
        super().__init__()
        self.render_mode = render_mode

        # Параметры среды (идентичны CartPole-v1)
        self.gravity = 9.81     # Ускорение свободного падения
        self.masscart = 1.0     # Масса тележки (cart)
        self.masspole = 0.1     # Масса палки (pole)
        self.total_mass = self.masspole + self.masscart # Общая масса маятника
        self.length = 0.5       # Половина длины палки (центр масс в середине)
        self.polemass_length = self.masspole * self.length # Момент инерции палки
        self.force_mag = 10.0   # Сила, с которой мы толкаем тележку
        self.tau = 0.02         # Шаг времени (dt, дискретизация среды)
        self.kinematics_integrator = 'euler' # Метод аппроксимации производных

        # Границы состояний (переход в терминальное состояние)
        self.x_threshold = 2.4  # граница по горизонтальной оси
        self.theta_threshold_radians = 12 * 2 * np.pi / 360  # 12 градусов (в рад)

        # Пространства
        self.action_space = spaces.Discrete(2)  # дискретное для действий (0 влево, 1 вправо)
        self.observation_space = spaces.Box(    # непрерывное для состяния (в 2 раза больше для стабильности)
            low=np.array([-self.x_threshold * 2, -np.inf, -self.theta_threshold_radians * 2, -np.inf]),
            high=np.array([self.x_threshold * 2, np.inf, self.theta_threshold_radians * 2, np.inf]),
            # dtype=np.float32
        )

        # Внутреннее состояние
        self.state = None
        self.steps_beyond_terminated = None

    def step(self, action):
        assert self.action_space.contains(action), f"Invalid action {action}" # действие корректно
        assert self.state is not None, "Call reset() before step()" # состояние инициализировано

        x, x_dot, theta, theta_dot = self.state # извлечение текущего состояния

        # Наше действие - толкаем тележку право или влево
        force = self.force_mag if action == 1 else -self.force_mag

        # Физика среды (обратный маятник)
        costheta = np.cos(theta)
        sintheta = np.sin(theta)
        temp = (force + self.polemass_length * theta_dot * theta_dot * sintheta) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (self.length * (4.0/3.0 - self.masspole * costheta * costheta / self.total_mass))
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        if self.kinematics_integrator == 'euler': # расчёт нового состояния
            x = x + self.tau * x_dot
            x_dot = x_dot + self.tau * xacc
            theta = theta + self.tau * theta_dot
            theta_dot = theta_dot + self.tau * thetaacc
        else:
            x_dot = x_dot + self.tau * xacc
            x = x + self.tau * x_dot
            theta_dot = theta_dot + self.tau * thetaacc
            theta = theta + self.tau * theta_dot

        self.state = (x, x_dot, theta, theta_dot) # обновление состояния

        # Проверка терминального состояния
        terminated = bool(
            x < -self.x_threshold or x > self.x_threshold or
            theta < -self.theta_threshold_radians or theta > self.theta_threshold_radians
        )

        # Награда: +1 за каждый шаг пока эпизод не завершен
        if not terminated:
            reward = 1.0
        elif self.steps_beyond_terminated is None:
            self.steps_beyond_terminated = 0
            reward = 1.0
        else:
            if self.steps_beyond_terminated == 0:
                print("Episode terminated!")
            self.steps_beyond_terminated += 1
            reward = 0.0

        truncated = False  # без лимита шагов

        return np.array(self.state, dtype=np.float32), reward, terminated, truncated, {}

    def reset(self, seed=None, options=None): # сброс среды
        super().reset(seed=seed)
        # Инициализация близко к центру
        self.state = np.random.uniform(low=-0.05, high=0.05, size=(4,))
        self.steps_beyond_terminated = None
        return np.array(self.state, dtype=np.float32), {}

    def render(self, mode="human"): # для визуализации
        if self.render_mode == "rgb_array":
            return self._render_rgb_array()
        else:
            self._render_human()

    def _render_human(self):
        # Вывод положения в консоль
        x, _, theta, _ = self.state
        print(f"Cart position: {x:.2f}, Pole angle: {theta:.2f} rad")

    def _render_rgb_array(self):
        # Визуализация через matplotlib
        fig, ax = plt.subplots(figsize=(6, 4))

        ax.clear()

        ax.set_xlim(-self.x_threshold, self.x_threshold) # границы
        ax.set_ylim(-0.7, 0.7)
        ax.axis('off') # убираем оси

        # Тележка (влияет только на визуализацию, как и все в этой функции)
        cart_width, cart_height = 0.4, 0.1
        cart = Rectangle((self.state[0] - cart_width/2, -cart_height/2), cart_width, cart_height, color='blue')
        ax.add_patch(cart)

        # Палка
        pole_x = self.state[0]
        pole_y = 0
        pole_end_x = pole_x + self.length * np.sin(self.state[2])
        pole_end_y = pole_y + self.length * np.cos(self.state[2])
        ax.plot([pole_x, pole_end_x], [pole_y, pole_end_y], 'r-', linewidth=3)

        fig.canvas.draw()
        img = np.frombuffer(fig.canvas.buffer_rgba(), dtype=np.uint8)
        img = img.reshape(fig.canvas.get_width_height()[::-1] + (4,))
        plt.close(fig)
        return img[:, :, :3]  # RGB без alpha
# Out:
# Overwriting RL_course_2/gymnasium_env_RL_course/envs/cartpole_env.py

# %% [markdown]
# ## Создание цикла обучения DQN: cartpole_DQN_train.py
#
# В этом скрипте мы:
# - Создаем класс DQN и инициализируем сеть
# - Инициализируем созданную ранее среду
# - Обучаем ее в ней, выводя награды каждый эпизод
# - Сохраняем обученную модель
# - Сохраняем графики с гиперпараметрами

# %%
# %%writefile RL_course_2/gymnasium_env_RL_course/envs/cartpole_DQN_train.py

import gymnasium as gym
import gymnasium_env_RL_course
from gymnasium.wrappers import NormalizeObservation
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

seed = 40000
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# Параметры
# ENV_NAME = 'CartPole-v1'
ENV_NAME = 'gymnasium_env_RL_course/CartPoleEnv-v0'
EPISODES = 300  # > 200 Количество эпизодов обучения
MAX_STEPS = 500  # 200-1000 Лимит шагов в эпизоде
GAMMA = 0.99  # 0.9-0.999 Коэффициент дисконтирования
EPSILON_START = 1.0  # 0.8-1 Начальный epsilon
EPSILON_END = 0.01   # 0.001-0.05 Минимальный epsilon
EPSILON_DECAY = 0.95  # 0.9-0.999 Уменьшение epsilon
BATCH_SIZE = 128  # 32-256 Размер батча
LR = 0.002  # 0.0001-0.005 Скорость обучения
MEMORY_SIZE = 20000  # 10000-100000, Размер replay buffer
TARGET_UPDATE = 2  # 1-10 Частота обновления target network

# Определяем Q-сеть (нейросеть - аппроксиматор Q функции)
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Буфер
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity) # очередь фикс размера

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return np.array(states), np.array(actions), np.array(rewards), np.array(next_states), np.array(dones)

    def __len__(self):
        return len(self.buffer)

# Выбор действия
def select_action(state, epsilon, policy_net, action_dim):
    if random.random() < epsilon:
        return random.randint(0, action_dim - 1) # случайное действие с вероятностью epsilon
    else:
        with torch.no_grad():
            state = torch.FloatTensor(state).unsqueeze(0)
            q_values = policy_net(state)
            return q_values.argmax().item() # действие с максимальным Q

# Обучение
def train_step(policy_net, target_net, optimizer, replay_buffer, batch_size, gamma):
    if len(replay_buffer) < batch_size: # достаточно ли данных
        return

    states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
    # Преобразование в тензоры
    states = torch.FloatTensor(states)
    actions = torch.LongTensor(actions).unsqueeze(1)
    rewards = torch.FloatTensor(rewards).unsqueeze(1)
    next_states = torch.FloatTensor(next_states)
    dones = torch.FloatTensor(dones).unsqueeze(1)

    # Вычисляем Q-values для текущих состояний и отбираем те которые соотв действиям агента
    q_values = policy_net(states).gather(1, actions)

    # Q-values для следующих состояний (используем target_net)
    next_q_values = target_net(next_states).max(1, keepdim=True)[0]
    target_q_values = rewards + (1 - dones) * gamma * next_q_values

    # Loss и обновление весов
    loss = nn.MSELoss()(q_values, target_q_values)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# Основной код
if __name__ == "__main__":
    env = gym.make(ENV_NAME) # создание среды
    normalizaton = 'Off'
    env, normalizaton = NormalizeObservation(env), 'On' # Включение нормализации

    state_dim = env.observation_space.shape[0] # инициализация состояния
    action_dim = env.action_space.n # инициализация действия

    policy_net = DQN(state_dim, action_dim) # инициализация сетей
    target_net = DQN(state_dim, action_dim)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=LR)
    replay_buffer = ReplayBuffer(MEMORY_SIZE)

    epsilon = EPSILON_START # сброс
    rewards_history = []

    # В каждом эпизоде:
    for episode in range(EPISODES):
        state, _ = env.reset() # сброс
        total_reward = 0

        # Среда рассчитывается до завершения эпизода:
        for step in range(MAX_STEPS):
            action = select_action(state, epsilon, policy_net, action_dim)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated # терминальное состояние или завершение по времени

            replay_buffer.push(state, action, reward, next_state, done)
            train_step(policy_net, target_net, optimizer, replay_buffer, BATCH_SIZE, GAMMA)

            state = next_state
            total_reward += reward

            if done:
                break

        # Уменьшение epsilon
        epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)

        # Обновление target network
        if episode % TARGET_UPDATE == 0:
            target_net.load_state_dict(policy_net.state_dict())

        rewards_history.append(total_reward)
        print(f"Episode {episode + 1}/{EPISODES}, Reward: {total_reward}, Epsilon: {epsilon:.3f}")

    env.close()

    # Сохранение модели
    torch.save({
        'policy_net_state_dict': policy_net.state_dict(),
        'state_dim': state_dim,
        'action_dim': action_dim,
        # Опционально:
        # 'epsilon': epsilon,
        # 'GAMMA': GAMMA,
        # 'LR': LR
    }, 'dqn_model.pth')  # Сохраняет в файл dqn_model.pth

    # Графики обучения
    plt.figure(figsize=(10, 5))
    plt.plot(rewards_history, linewidth=1.25, color='b')
    plt.title('Награда за эпизод')
    plt.xlabel('Эпизод')
    plt.ylabel('Награда')
    plt.grid(True)
    plt.savefig('training_DQN.png', dpi=300)
    # plt.show()

    # Скользящее среднее для сглаживания графика
    window_size = 25
    if len(rewards_history) >= window_size:
        moving_avg = np.convolve(rewards_history, np.ones(window_size)/window_size, mode='valid')
        plt.figure(figsize=(10, 5))
        plt.plot(rewards_history, linewidth=1, color='b', alpha=0.5)
        plt.plot(moving_avg, linewidth=2, color='b')
        plt.title(f'Скользящее среднее наград (M = {window_size}),\n$\\gamma = ${GAMMA}, $\\epsilon_d$ = {EPSILON_DECAY}, $learning\ rate = ${LR}, Normalization = {normalizaton}, seed = {seed}')
        plt.xlabel('Эпизод')
        plt.ylabel('Средняя награда')
        plt.grid(True)
        plt.savefig('training_DQN_RunMean.png', dpi=300)
        plt.show()
# Out:
# Overwriting RL_course_2/gymnasium_env_RL_course/envs/cartpole_DQN_train.py

# %% [markdown]
# ## Создание скрипта для оценки модели и создания анимации: run_catpole_DQN.py
#
# В этом скрипте мы:
# - Инициализируем созданную ранее среду
# - Инициализируем DQN и загружаем обученные веса
# - Прогоняем эпизоды с обученным DQN агентом и сохраняем GIF

# %%
# %%writefile RL_course_2/run_catpole_DQN.py

import gymnasium as gym
from gymnasium.wrappers import NormalizeObservation
import torch
import torch.nn as nn
import sys
import os
import numpy as np
import imageio
from pyvirtualdisplay import Display

project_root = os.path.dirname(os.path.abspath(__file__))  # Путь к корню проекта для импорта DQN
sys.path.append(project_root)
from gymnasium_env_RL_course.envs.cartpole_DQN_train import DQN

gif_filename = 'cartpole_test_DQN.gif'
fps = 15
# Параметры
# ENV_NAME = 'CartPole-v1'  # оригинальна среда
ENV_NAME = 'gymnasium_env_RL_course/CartPoleEnv-v0' # кастомная среда
STATE_DIM = 4  # позиции и скорости тележки и палки
ACTION_DIM = 2  # втолкаем вправо или влево
MAX_STEPS = 500  # лимит шагов, чтобы избежать зависания среды при успешном агенте

# Создание сети
policy_net = DQN(STATE_DIM, ACTION_DIM) # создаем такой же DQN как при обучении
policy_net.eval() # режим оценки

# Загрузка модели, обученной ранее
checkpoint = torch.load('dqn_model.pth', map_location=torch.device('cpu'), weights_only=False) # cpu, с метаданными
policy_net.load_state_dict(checkpoint['policy_net_state_dict'])
print("Модель загружена")

# Создание среды
env = gym.make(ENV_NAME, render_mode='rgb_array') # rgb array позволяет собирать кадры для gif
env = NormalizeObservation(env) # включение нормализации

# Функция для выбора действия без epsilon
def select_action(state, policy_net):
    with torch.no_grad():
        state = torch.FloatTensor(state).unsqueeze(0) # добавляем размерность батча
        q_values = policy_net(state)
        return q_values.argmax().item()

# Оценка модели
with Display(visible=0, size=(400, 300)):  # Виртуальный дисплей для фикса рендеринга в колабе

    NUM_EVAL_EPISODES = 10
    rewards = []
    all_frames = []
    for episode in range(NUM_EVAL_EPISODES):
        state, _ = env.reset() # сброс среды
        total_reward = 0
        done = False
        step_count = 0  #счётчик шагов для truncated
        while not done and step_count < MAX_STEPS:
            action = select_action(state, policy_net)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            state = next_state
            total_reward += reward
            step_count += 1
            img = env.render()
            if isinstance(img, np.ndarray):
                all_frames.append(img[:, :, :3])  # RGB
        rewards.append(total_reward)
        print(f"Оценка эпизода {episode + 1}: Награда = {total_reward}")

    mean_reward = sum(rewards) / len(rewards)
    print(f"Средняя награда за {NUM_EVAL_EPISODES} эпизодов: {mean_reward:.2f}")

    imageio.mimsave(gif_filename, all_frames, fps=fps)
    print(f"GIF сохранён: {gif_filename}")

env.close()
# Out:
# Overwriting RL_course_2/run_catpole_DQN.py

# %% [markdown]
# ## Создание скрипта для демонстрации среды: run_env.py
#
# В этом скрипте мы:
# - Инициализируем среду
# - Записываем в гифку эпизоды со случайным агентом или агентом, управляемым с клавиатуры

# %%
# %%writefile RL_course_2/run_env.py

import gymnasium_env_RL_course
import gymnasium as gym
import imageio
import os

OUTPUT_DIR = '/content/RL_course_2'
GIF_FILENAME = 'cartpole_test.gif' # имя GIF

env_id = 'gymnasium_env_RL_course/CartPoleEnv-v0'
num_steps = 100
render_mode = 'rgb_array'

gif_save_path = os.path.join(OUTPUT_DIR, GIF_FILENAME)

env = gym.make('gymnasium_env_RL_course/CartPoleEnv-v0', render_mode=render_mode)

obs, info = env.reset()
total_reward = 0
all_frames = []

for step in range(num_steps):
    # action = env.action_space.sample() # рандомное действие
    action = int(input("Action (0=left, 1=right): ")) # 0 - влево, 1 - вправо

    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward

    frame = env.render()
    all_frames.append(frame)

    if terminated or truncated:
        print(f"Эпизод завершен, общая награда: {total_reward}")
        break

env.close()

if all_frames:
    imageio.mimsave(gif_save_path, all_frames, duration=0.05, loop=0)
    print(f"GIF сохранен: {gif_save_path}")
# Out:
# Overwriting RL_course_2/run_env.py

# %% [markdown]
# ## Сборка проекта
# Сборка проекта выполняется для установки зависимостей, регистрации сред в Gymnasium и добавления ссылок (что позволяет делать `import`)

# %%
# !pip install -e RL_course_2/.
# Out:
# Obtaining file:///content/RL_course_2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (from gymnasium_env_RL_course==0.0.1) (1.2.2)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.12/dist-packages (from gymnasium_env_RL_course==0.0.1) (4.3.0)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium_env_RL_course==0.0.1) (2.6.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gymnasium_env_RL_course==0.0.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gymnasium_env_RL_course==0.0.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gymnasium_env_RL_course==0.0.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gymnasium_env_RL_course==0.0.1) (0.0.4)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->gymnasium_env_RL_course==0.0.1) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->gymnasium_env_RL_course==0.0.1) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit->gymnasium_env_RL_course==0.0.1) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit->gymnasium_env_RL_course==0.0.1) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->gymnasium_env_RL_course==0.0.1) (20.35.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->gymnasium_env_RL_course==0.0.1) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->gymnasium_env_RL_course==0.0.1) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->gymnasium_env_RL_course==0.0.1) (4.5.0)
# Building wheels for collected packages: gymnasium_env_RL_course
#   Building editable for gymnasium_env_RL_course (pyproject.toml) ... done
#   Created wheel for gymnasium_env_RL_course: filename=gymnasium_env_rl_course-0.0.1-py2.py3-none-any.whl size=1088 sha256=af4359ac421f4b2c57564f737b05fc78436cb65e1c9bf3481c30c9bb6624eadc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f3ej6hy8/wheels/66/14/bb/1de38ad51487621c303120da0155ce35ed84b5ea2dfb6c2150
# Successfully built gymnasium_env_RL_course
# Installing collected packages: gymnasium_env_RL_course
#   Attempting uninstall: gymnasium_env_RL_course
#     Found existing installation: gymnasium_env_RL_course 0.0.1
#     Uninstalling gymnasium_env_RL_course-0.0.1:
#       Successfully uninstalled gymnasium_env_RL_course-0.0.1
# Successfully installed gymnasium_env_RL_course-0.0.1

# %% [markdown]
# ## Выполнение созданных ранее скриптов
# Сначала мы запустим скрипт, который просто покажет среду, которую мы создали. Можно вручную поуправлять обратным маятником или посмотреть на случайное поведение агента (для этого надо раскомментровать строку в `run_env.py` и запустить скрипт заново):

# %%
# !cd /content/RL_course_2/ && python run_env.py

from IPython.display import Image, display
gif_path = 'RL_course_2/cartpole_test.gif'
try:
    display(Image(filename=gif_path, width=500))
except FileNotFoundError:
    print(f"Ошибка: Файл GIF '{gif_path}' не найден.")
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 0
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 0
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 0
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 0
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 0
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Action (0=left, 1=right): 1
# Эпизод завершен, общая награда: 20.0
# GIF сохранен: /content/RL_course_2/cartpole_test.gif

# %% [markdown]
# ### Обучение DQN
#
# Теперь перейдем к обучению нашего DQN-агента.
#
# Далее в терминал будет выводиться номер эпизода, награда за него и эпсилон ε, актуальная для этого эпизода.
#
# Можно увидеть, что эпсилон (вероятность совершения случайного действия) со временем экспонентециально уменьшается, это соответствует нашей деградирующей ε-жадной стратегии (decaying epsilon-greedy strategy).

# %%
# !cd /content/RL_course_2/ && python gymnasium_env_RL_course/envs/cartpole_DQN_train.py
# Out:
# /content/RL_course_2/gymnasium_env_RL_course/envs/cartpole_DQN_train.py:177: SyntaxWarning: invalid escape sequence '\ '
#   plt.title(f'Скользящее среднее наград (M = {window_size}),\n$\\gamma = ${GAMMA}, $\\epsilon_d$ = {EPSILON_DECAY}, $learning\ rate = ${LR}, Normalization = {normalizaton}, seed = {seed}')
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Episode 1/500, Reward: 14.0, Epsilon: 0.997
# Episode 2/500, Reward: 56.0, Epsilon: 0.994
# Episode 3/500, Reward: 13.0, Epsilon: 0.991
# Episode 4/500, Reward: 31.0, Epsilon: 0.988
# Episode 5/500, Reward: 12.0, Epsilon: 0.985
# Episode 6/500, Reward: 11.0, Epsilon: 0.982
# Episode 7/500, Reward: 17.0, Epsilon: 0.979
# Episode 8/500, Reward: 25.0, Epsilon: 0.976
# Episode 9/500, Reward: 13.0, Epsilon: 0.973
# Episode 10/500, Reward: 31.0, Epsilon: 0.970
# Episode 11/500, Reward: 20.0, Epsilon: 0.967
# Episode 12/500, Reward: 9.0, Epsilon: 0.965
# Episode 13/500, Reward: 31.0, Epsilon: 0.962
# Episode 14/500, Reward: 29.0, Epsilon: 0.959
# Episode 15/500, Reward: 11.0, Epsilon: 0.956
# Episode 16/500, Reward: 37.0, Epsilon: 0.953
# Episode 17/500, Reward: 25.0, Epsilon: 0.950
# Episode 18/500, Reward: 25.0, Epsilon: 0.947
# Episode 19/500, Reward: 14.0, Epsilon: 0.945
# Episode 20/500, Reward: 21.0, Epsilon: 0.942
# Episode 21/500, Reward: 14.0, Epsilon: 0.939
# Episode 22/500, Reward: 14.0, Epsilon: 0.936
# Episode 23/500, Reward: 23.0, Epsilon: 0.933
# Episode 24/500, Reward: 23.0, Epsilon: 0.930
# Episode 25/500, Reward: 11.0, Epsilon: 0.928
# Episode 26/500, Reward: 19.0, Epsilon: 0.925
# Episode 27/500, Reward: 17.0, Epsilon: 0.922
# Episode 28/500, Reward: 30.0, Epsilon: 0.919
# Episode 29/500, Reward: 30.0, Epsilon: 0.917
# Episode 30/500, Reward: 20.0, Epsilon: 0.914
# Episode 31/500, Reward: 17.0, Epsilon: 0.911
# Episode 32/500, Reward: 32.0, Epsilon: 0.908
# Episode 33/500, Reward: 26.0, Epsilon: 0.906
# Episode 34/500, Reward: 17.0, Epsilon: 0.903
# Episode 35/500, Reward: 15.0, Epsilon: 0.900
# Episode 36/500, Reward: 13.0, Epsilon: 0.897
# Episode 37/500, Reward: 25.0, Epsilon: 0.895
# Episode 38/500, Reward: 28.0, Epsilon: 0.892
# Episode 39/500, Reward: 14.0, Epsilon: 0.889
# Episode 40/500, Reward: 27.0, Epsilon: 0.887
# Episode 41/500, Reward: 17.0, Epsilon: 0.884
# Episode 42/500, Reward: 25.0, Epsilon: 0.881
# Episode 43/500, Reward: 87.0, Epsilon: 0.879
# Episode 44/500, Reward: 11.0, Epsilon: 0.876
# Episode 45/500, Reward: 22.0, Epsilon: 0.874
# Episode 46/500, Reward: 13.0, Epsilon: 0.871
# Episode 47/500, Reward: 22.0, Epsilon: 0.868
# Episode 48/500, Reward: 31.0, Epsilon: 0.866
# Episode 49/500, Reward: 41.0, Epsilon: 0.863
# Episode 50/500, Reward: 13.0, Epsilon: 0.861
# Episode 51/500, Reward: 17.0, Epsilon: 0.858
# Episode 52/500, Reward: 18.0, Epsilon: 0.855
# Episode 53/500, Reward: 40.0, Epsilon: 0.853
# Episode 54/500, Reward: 32.0, Epsilon: 0.850
# Episode 55/500, Reward: 30.0, Epsilon: 0.848
# Episode 56/500, Reward: 23.0, Epsilon: 0.845
# Episode 57/500, Reward: 31.0, Epsilon: 0.843
# Episode 58/500, Reward: 20.0, Epsilon: 0.840
# Episode 59/500, Reward: 19.0, Epsilon: 0.838
# Episode 60/500, Reward: 11.0, Epsilon: 0.835
# Episode 61/500, Reward: 65.0, Epsilon: 0.833
# Episode 62/500, Reward: 20.0, Epsilon: 0.830
# Episode 63/500, Reward: 27.0, Epsilon: 0.828
# Episode 64/500, Reward: 52.0, Epsilon: 0.825
# Episode 65/500, Reward: 30.0, Epsilon: 0.823
# Episode 66/500, Reward: 23.0, Epsilon: 0.820
# Episode 67/500, Reward: 47.0, Epsilon: 0.818
# Episode 68/500, Reward: 31.0, Epsilon: 0.815
# Episode 69/500, Reward: 58.0, Epsilon: 0.813
# Episode 70/500, Reward: 40.0, Epsilon: 0.810
# Episode 71/500, Reward: 58.0, Epsilon: 0.808
# Episode 72/500, Reward: 13.0, Epsilon: 0.805
# Episode 73/500, Reward: 17.0, Epsilon: 0.803
# Episode 74/500, Reward: 11.0, Epsilon: 0.801
# Episode 75/500, Reward: 34.0, Epsilon: 0.798
# Episode 76/500, Reward: 20.0, Epsilon: 0.796
# Episode 77/500, Reward: 55.0, Epsilon: 0.793
# Episode 78/500, Reward: 82.0, Epsilon: 0.791
# Episode 79/500, Reward: 16.0, Epsilon: 0.789
# Episode 80/500, Reward: 79.0, Epsilon: 0.786
# Episode 81/500, Reward: 14.0, Epsilon: 0.784
# Episode 82/500, Reward: 46.0, Epsilon: 0.782
# Episode 83/500, Reward: 32.0, Epsilon: 0.779
# Episode 84/500, Reward: 13.0, Epsilon: 0.777
# Episode 85/500, Reward: 59.0, Epsilon: 0.775
# Episode 86/500, Reward: 86.0, Epsilon: 0.772
# Episode 87/500, Reward: 41.0, Epsilon: 0.770
# Episode 88/500, Reward: 43.0, Epsilon: 0.768
# Episode 89/500, Reward: 20.0, Epsilon: 0.765
# Episode 90/500, Reward: 15.0, Epsilon: 0.763
# Episode 91/500, Reward: 20.0, Epsilon: 0.761
# Episode 92/500, Reward: 12.0, Epsilon: 0.758
# Episode 93/500, Reward: 30.0, Epsilon: 0.756
# Episode 94/500, Reward: 46.0, Epsilon: 0.754
# Episode 95/500, Reward: 47.0, Epsilon: 0.752
# Episode 96/500, Reward: 15.0, Epsilon: 0.749
# Episode 97/500, Reward: 24.0, Epsilon: 0.747
# Episode 98/500, Reward: 19.0, Epsilon: 0.745
# Episode 99/500, Reward: 35.0, Epsilon: 0.743
# Episode 100/500, Reward: 19.0, Epsilon: 0.740
# Episode 101/500, Reward: 33.0, Epsilon: 0.738
# Episode 102/500, Reward: 22.0, Epsilon: 0.736
# Episode 103/500, Reward: 55.0, Epsilon: 0.734
# Episode 104/500, Reward: 34.0, Epsilon: 0.732
# Episode 105/500, Reward: 28.0, Epsilon: 0.729
# Episode 106/500, Reward: 56.0, Epsilon: 0.727
# Episode 107/500, Reward: 42.0, Epsilon: 0.725
# Episode 108/500, Reward: 67.0, Epsilon: 0.723
# Episode 109/500, Reward: 221.0, Epsilon: 0.721
# Episode 110/500, Reward: 20.0, Epsilon: 0.719
# Episode 111/500, Reward: 14.0, Epsilon: 0.716
# Episode 112/500, Reward: 31.0, Epsilon: 0.714
# Episode 113/500, Reward: 11.0, Epsilon: 0.712
# Episode 114/500, Reward: 62.0, Epsilon: 0.710
# Episode 115/500, Reward: 16.0, Epsilon: 0.708
# Episode 116/500, Reward: 36.0, Epsilon: 0.706
# Episode 117/500, Reward: 70.0, Epsilon: 0.704
# Episode 118/500, Reward: 17.0, Epsilon: 0.702
# Episode 119/500, Reward: 12.0, Epsilon: 0.699
# Episode 120/500, Reward: 18.0, Epsilon: 0.697
# Episode 121/500, Reward: 15.0, Epsilon: 0.695
# Episode 122/500, Reward: 20.0, Epsilon: 0.693
# Episode 123/500, Reward: 36.0, Epsilon: 0.691
# Episode 124/500, Reward: 117.0, Epsilon: 0.689
# Episode 125/500, Reward: 14.0, Epsilon: 0.687
# Episode 126/500, Reward: 13.0, Epsilon: 0.685
# Episode 127/500, Reward: 13.0, Epsilon: 0.683
# Episode 128/500, Reward: 19.0, Epsilon: 0.681
# Episode 129/500, Reward: 52.0, Epsilon: 0.679
# Episode 130/500, Reward: 84.0, Epsilon: 0.677
# Episode 131/500, Reward: 25.0, Epsilon: 0.675
# Episode 132/500, Reward: 17.0, Epsilon: 0.673
# Episode 133/500, Reward: 12.0, Epsilon: 0.671
# Episode 134/500, Reward: 19.0, Epsilon: 0.669
# Episode 135/500, Reward: 23.0, Epsilon: 0.667
# Episode 136/500, Reward: 15.0, Epsilon: 0.665
# Episode 137/500, Reward: 14.0, Epsilon: 0.663
# Episode 138/500, Reward: 14.0, Epsilon: 0.661
# Episode 139/500, Reward: 19.0, Epsilon: 0.659
# Episode 140/500, Reward: 120.0, Epsilon: 0.657
# Episode 141/500, Reward: 18.0, Epsilon: 0.655
# Episode 142/500, Reward: 38.0, Epsilon: 0.653
# Episode 143/500, Reward: 30.0, Epsilon: 0.651
# Episode 144/500, Reward: 30.0, Epsilon: 0.649
# Episode 145/500, Reward: 18.0, Epsilon: 0.647
# Episode 146/500, Reward: 14.0, Epsilon: 0.645
# Episode 147/500, Reward: 30.0, Epsilon: 0.643
# Episode 148/500, Reward: 27.0, Epsilon: 0.641
# Episode 149/500, Reward: 20.0, Epsilon: 0.639
# Episode 150/500, Reward: 25.0, Epsilon: 0.637
# Episode 151/500, Reward: 99.0, Epsilon: 0.635
# Episode 152/500, Reward: 78.0, Epsilon: 0.633
# Episode 153/500, Reward: 29.0, Epsilon: 0.631
# Episode 154/500, Reward: 12.0, Epsilon: 0.630
# Episode 155/500, Reward: 39.0, Epsilon: 0.628
# Episode 156/500, Reward: 38.0, Epsilon: 0.626
# Episode 157/500, Reward: 22.0, Epsilon: 0.624
# Episode 158/500, Reward: 16.0, Epsilon: 0.622
# Episode 159/500, Reward: 90.0, Epsilon: 0.620
# Episode 160/500, Reward: 111.0, Epsilon: 0.618
# Episode 161/500, Reward: 24.0, Epsilon: 0.616
# Episode 162/500, Reward: 11.0, Epsilon: 0.615
# Episode 163/500, Reward: 13.0, Epsilon: 0.613
# Episode 164/500, Reward: 39.0, Epsilon: 0.611
# Episode 165/500, Reward: 26.0, Epsilon: 0.609
# Episode 166/500, Reward: 15.0, Epsilon: 0.607
# Episode 167/500, Reward: 21.0, Epsilon: 0.605
# Episode 168/500, Reward: 30.0, Epsilon: 0.604
# Episode 169/500, Reward: 34.0, Epsilon: 0.602
# Episode 170/500, Reward: 27.0, Epsilon: 0.600
# Episode 171/500, Reward: 27.0, Epsilon: 0.598
# Episode 172/500, Reward: 21.0, Epsilon: 0.596
# Episode 173/500, Reward: 19.0, Epsilon: 0.595
# Episode 174/500, Reward: 14.0, Epsilon: 0.593
# Episode 175/500, Reward: 22.0, Epsilon: 0.591
# Episode 176/500, Reward: 18.0, Epsilon: 0.589
# Episode 177/500, Reward: 44.0, Epsilon: 0.588
# Episode 178/500, Reward: 63.0, Epsilon: 0.586
# Episode 179/500, Reward: 44.0, Epsilon: 0.584
# Episode 180/500, Reward: 24.0, Epsilon: 0.582
# Episode 181/500, Reward: 14.0, Epsilon: 0.581
# Episode 182/500, Reward: 17.0, Epsilon: 0.579
# Episode 183/500, Reward: 71.0, Epsilon: 0.577
# Episode 184/500, Reward: 11.0, Epsilon: 0.575
# Episode 185/500, Reward: 21.0, Epsilon: 0.574
# Episode 186/500, Reward: 13.0, Epsilon: 0.572
# Episode 187/500, Reward: 17.0, Epsilon: 0.570
# Episode 188/500, Reward: 92.0, Epsilon: 0.568
# Episode 189/500, Reward: 12.0, Epsilon: 0.567
# Episode 190/500, Reward: 10.0, Epsilon: 0.565
# Episode 191/500, Reward: 24.0, Epsilon: 0.563
# Episode 192/500, Reward: 15.0, Epsilon: 0.562
# Episode 193/500, Reward: 18.0, Epsilon: 0.560
# Episode 194/500, Reward: 20.0, Epsilon: 0.558
# Episode 195/500, Reward: 27.0, Epsilon: 0.557
# Episode 196/500, Reward: 90.0, Epsilon: 0.555
# Episode 197/500, Reward: 17.0, Epsilon: 0.553
# Episode 198/500, Reward: 13.0, Epsilon: 0.552
# Episode 199/500, Reward: 100.0, Epsilon: 0.550
# Episode 200/500, Reward: 15.0, Epsilon: 0.548
# Episode 201/500, Reward: 11.0, Epsilon: 0.547
# Episode 202/500, Reward: 19.0, Epsilon: 0.545
# Episode 203/500, Reward: 11.0, Epsilon: 0.543
# Episode 204/500, Reward: 18.0, Epsilon: 0.542
# Episode 205/500, Reward: 34.0, Epsilon: 0.540
# Episode 206/500, Reward: 19.0, Epsilon: 0.539
# Episode 207/500, Reward: 124.0, Epsilon: 0.537
# Episode 208/500, Reward: 62.0, Epsilon: 0.535
# Episode 209/500, Reward: 17.0, Epsilon: 0.534
# Episode 210/500, Reward: 10.0, Epsilon: 0.532
# Episode 211/500, Reward: 18.0, Epsilon: 0.530
# Episode 212/500, Reward: 38.0, Epsilon: 0.529
# Episode 213/500, Reward: 16.0, Epsilon: 0.527
# Episode 214/500, Reward: 90.0, Epsilon: 0.526
# Episode 215/500, Reward: 26.0, Epsilon: 0.524
# Episode 216/500, Reward: 36.0, Epsilon: 0.523
# Episode 217/500, Reward: 31.0, Epsilon: 0.521
# Episode 218/500, Reward: 17.0, Epsilon: 0.519
# Episode 219/500, Reward: 14.0, Epsilon: 0.518
# Episode 220/500, Reward: 10.0, Epsilon: 0.516
# Episode 221/500, Reward: 20.0, Epsilon: 0.515
# Episode 222/500, Reward: 16.0, Epsilon: 0.513
# Episode 223/500, Reward: 35.0, Epsilon: 0.512
# Episode 224/500, Reward: 39.0, Epsilon: 0.510
# Episode 225/500, Reward: 30.0, Epsilon: 0.509
# Episode 226/500, Reward: 26.0, Epsilon: 0.507
# Episode 227/500, Reward: 12.0, Epsilon: 0.506
# Episode 228/500, Reward: 23.0, Epsilon: 0.504
# Episode 229/500, Reward: 30.0, Epsilon: 0.503
# Episode 230/500, Reward: 42.0, Epsilon: 0.501
# Episode 231/500, Reward: 17.0, Epsilon: 0.500
# Episode 232/500, Reward: 19.0, Epsilon: 0.498
# Episode 233/500, Reward: 14.0, Epsilon: 0.497
# Episode 234/500, Reward: 122.0, Epsilon: 0.495
# Episode 235/500, Reward: 17.0, Epsilon: 0.494
# Episode 236/500, Reward: 19.0, Epsilon: 0.492
# Episode 237/500, Reward: 33.0, Epsilon: 0.491
# Episode 238/500, Reward: 33.0, Epsilon: 0.489
# Episode 239/500, Reward: 55.0, Epsilon: 0.488
# Episode 240/500, Reward: 112.0, Epsilon: 0.486
# Episode 241/500, Reward: 25.0, Epsilon: 0.485
# Episode 242/500, Reward: 28.0, Epsilon: 0.483
# Episode 243/500, Reward: 28.0, Epsilon: 0.482
# Episode 244/500, Reward: 27.0, Epsilon: 0.480
# Episode 245/500, Reward: 56.0, Epsilon: 0.479
# Episode 246/500, Reward: 113.0, Epsilon: 0.478
# Episode 247/500, Reward: 69.0, Epsilon: 0.476
# Episode 248/500, Reward: 16.0, Epsilon: 0.475
# Episode 249/500, Reward: 161.0, Epsilon: 0.473
# Episode 250/500, Reward: 120.0, Epsilon: 0.472
# Episode 251/500, Reward: 14.0, Epsilon: 0.470
# Episode 252/500, Reward: 27.0, Epsilon: 0.469
# Episode 253/500, Reward: 14.0, Epsilon: 0.468
# Episode 254/500, Reward: 30.0, Epsilon: 0.466
# Episode 255/500, Reward: 14.0, Epsilon: 0.465
# Episode 256/500, Reward: 102.0, Epsilon: 0.463
# Episode 257/500, Reward: 47.0, Epsilon: 0.462
# Episode 258/500, Reward: 18.0, Epsilon: 0.461
# Episode 259/500, Reward: 77.0, Epsilon: 0.459
# Episode 260/500, Reward: 120.0, Epsilon: 0.458
# Episode 261/500, Reward: 47.0, Epsilon: 0.456
# Episode 262/500, Reward: 90.0, Epsilon: 0.455
# Episode 263/500, Reward: 16.0, Epsilon: 0.454
# Episode 264/500, Reward: 52.0, Epsilon: 0.452
# Episode 265/500, Reward: 44.0, Epsilon: 0.451
# Episode 266/500, Reward: 18.0, Epsilon: 0.450
# Episode 267/500, Reward: 42.0, Epsilon: 0.448
# Episode 268/500, Reward: 46.0, Epsilon: 0.447
# Episode 269/500, Reward: 65.0, Epsilon: 0.446
# Episode 270/500, Reward: 21.0, Epsilon: 0.444
# Episode 271/500, Reward: 64.0, Epsilon: 0.443
# Episode 272/500, Reward: 10.0, Epsilon: 0.442
# Episode 273/500, Reward: 35.0, Epsilon: 0.440
# Episode 274/500, Reward: 51.0, Epsilon: 0.439
# Episode 275/500, Reward: 103.0, Epsilon: 0.438
# Episode 276/500, Reward: 19.0, Epsilon: 0.436
# Episode 277/500, Reward: 80.0, Epsilon: 0.435
# Episode 278/500, Reward: 29.0, Epsilon: 0.434
# Episode 279/500, Reward: 107.0, Epsilon: 0.432
# Episode 280/500, Reward: 12.0, Epsilon: 0.431
# Episode 281/500, Reward: 96.0, Epsilon: 0.430
# Episode 282/500, Reward: 139.0, Epsilon: 0.429
# Episode 283/500, Reward: 29.0, Epsilon: 0.427
# Episode 284/500, Reward: 65.0, Epsilon: 0.426
# Episode 285/500, Reward: 57.0, Epsilon: 0.425
# Episode 286/500, Reward: 113.0, Epsilon: 0.423
# Episode 287/500, Reward: 147.0, Epsilon: 0.422
# Episode 288/500, Reward: 38.0, Epsilon: 0.421
# Episode 289/500, Reward: 25.0, Epsilon: 0.420
# Episode 290/500, Reward: 15.0, Epsilon: 0.418
# Episode 291/500, Reward: 20.0, Epsilon: 0.417
# Episode 292/500, Reward: 101.0, Epsilon: 0.416
# Episode 293/500, Reward: 70.0, Epsilon: 0.415
# Episode 294/500, Reward: 103.0, Epsilon: 0.413
# Episode 295/500, Reward: 55.0, Epsilon: 0.412
# Episode 296/500, Reward: 22.0, Epsilon: 0.411
# Episode 297/500, Reward: 97.0, Epsilon: 0.410
# Episode 298/500, Reward: 108.0, Epsilon: 0.408
# Episode 299/500, Reward: 15.0, Epsilon: 0.407
# Episode 300/500, Reward: 13.0, Epsilon: 0.406
# Episode 301/500, Reward: 30.0, Epsilon: 0.405
# Episode 302/500, Reward: 13.0, Epsilon: 0.404
# Episode 303/500, Reward: 27.0, Epsilon: 0.402
# Episode 304/500, Reward: 30.0, Epsilon: 0.401
# Episode 305/500, Reward: 102.0, Epsilon: 0.400
# Episode 306/500, Reward: 17.0, Epsilon: 0.399
# Episode 307/500, Reward: 99.0, Epsilon: 0.398
# Episode 308/500, Reward: 106.0, Epsilon: 0.396
# Episode 309/500, Reward: 178.0, Epsilon: 0.395
# Episode 310/500, Reward: 116.0, Epsilon: 0.394
# Episode 311/500, Reward: 109.0, Epsilon: 0.393
# Episode 312/500, Reward: 108.0, Epsilon: 0.392
# Episode 313/500, Reward: 103.0, Epsilon: 0.390
# Episode 314/500, Reward: 17.0, Epsilon: 0.389
# Episode 315/500, Reward: 12.0, Epsilon: 0.388
# Episode 316/500, Reward: 20.0, Epsilon: 0.387
# Episode 317/500, Reward: 164.0, Epsilon: 0.386
# Episode 318/500, Reward: 118.0, Epsilon: 0.385
# Episode 319/500, Reward: 29.0, Epsilon: 0.383
# Episode 320/500, Reward: 22.0, Epsilon: 0.382
# Episode 321/500, Reward: 104.0, Epsilon: 0.381
# Episode 322/500, Reward: 101.0, Epsilon: 0.380
# Episode 323/500, Reward: 103.0, Epsilon: 0.379
# Episode 324/500, Reward: 48.0, Epsilon: 0.378
# Episode 325/500, Reward: 13.0, Epsilon: 0.377
# Episode 326/500, Reward: 99.0, Epsilon: 0.376
# Episode 327/500, Reward: 19.0, Epsilon: 0.374
# Episode 328/500, Reward: 31.0, Epsilon: 0.373
# Episode 329/500, Reward: 17.0, Epsilon: 0.372
# Episode 330/500, Reward: 31.0, Epsilon: 0.371
# Episode 331/500, Reward: 27.0, Epsilon: 0.370
# Episode 332/500, Reward: 27.0, Epsilon: 0.369
# Episode 333/500, Reward: 16.0, Epsilon: 0.368
# Episode 334/500, Reward: 98.0, Epsilon: 0.367
# Episode 335/500, Reward: 103.0, Epsilon: 0.365
# Episode 336/500, Reward: 17.0, Epsilon: 0.364
# Episode 337/500, Reward: 60.0, Epsilon: 0.363
# Episode 338/500, Reward: 79.0, Epsilon: 0.362
# Episode 339/500, Reward: 11.0, Epsilon: 0.361
# Episode 340/500, Reward: 101.0, Epsilon: 0.360
# Episode 341/500, Reward: 47.0, Epsilon: 0.359
# Episode 342/500, Reward: 14.0, Epsilon: 0.358
# Episode 343/500, Reward: 23.0, Epsilon: 0.357
# Episode 344/500, Reward: 30.0, Epsilon: 0.356
# Episode 345/500, Reward: 14.0, Epsilon: 0.355
# Episode 346/500, Reward: 18.0, Epsilon: 0.354
# Episode 347/500, Reward: 22.0, Epsilon: 0.353
# Episode 348/500, Reward: 103.0, Epsilon: 0.351
# Episode 349/500, Reward: 23.0, Epsilon: 0.350
# Episode 350/500, Reward: 16.0, Epsilon: 0.349
# Episode 351/500, Reward: 40.0, Epsilon: 0.348
# Episode 352/500, Reward: 104.0, Epsilon: 0.347
# Episode 353/500, Reward: 15.0, Epsilon: 0.346
# Episode 354/500, Reward: 23.0, Epsilon: 0.345
# Episode 355/500, Reward: 61.0, Epsilon: 0.344
# Episode 356/500, Reward: 24.0, Epsilon: 0.343
# Episode 357/500, Reward: 24.0, Epsilon: 0.342
# Episode 358/500, Reward: 101.0, Epsilon: 0.341
# Episode 359/500, Reward: 23.0, Epsilon: 0.340
# Episode 360/500, Reward: 14.0, Epsilon: 0.339
# Episode 361/500, Reward: 31.0, Epsilon: 0.338
# Episode 362/500, Reward: 107.0, Epsilon: 0.337
# Episode 363/500, Reward: 13.0, Epsilon: 0.336
# Episode 364/500, Reward: 151.0, Epsilon: 0.335
# Episode 365/500, Reward: 114.0, Epsilon: 0.334
# Episode 366/500, Reward: 105.0, Epsilon: 0.333
# Episode 367/500, Reward: 89.0, Epsilon: 0.332
# Episode 368/500, Reward: 17.0, Epsilon: 0.331
# Episode 369/500, Reward: 20.0, Epsilon: 0.330
# Episode 370/500, Reward: 21.0, Epsilon: 0.329
# Episode 371/500, Reward: 30.0, Epsilon: 0.328
# Episode 372/500, Reward: 13.0, Epsilon: 0.327
# Episode 373/500, Reward: 22.0, Epsilon: 0.326
# Episode 374/500, Reward: 84.0, Epsilon: 0.325
# Episode 375/500, Reward: 115.0, Epsilon: 0.324
# Episode 376/500, Reward: 17.0, Epsilon: 0.323
# Episode 377/500, Reward: 117.0, Epsilon: 0.322
# Episode 378/500, Reward: 21.0, Epsilon: 0.321
# Episode 379/500, Reward: 34.0, Epsilon: 0.320
# Episode 380/500, Reward: 28.0, Epsilon: 0.319
# Episode 381/500, Reward: 29.0, Epsilon: 0.318
# Episode 382/500, Reward: 99.0, Epsilon: 0.317
# Episode 383/500, Reward: 113.0, Epsilon: 0.316
# Episode 384/500, Reward: 105.0, Epsilon: 0.315
# Episode 385/500, Reward: 46.0, Epsilon: 0.315
# Episode 386/500, Reward: 18.0, Epsilon: 0.314
# Episode 387/500, Reward: 19.0, Epsilon: 0.313
# Episode 388/500, Reward: 81.0, Epsilon: 0.312
# Episode 389/500, Reward: 106.0, Epsilon: 0.311
# Episode 390/500, Reward: 23.0, Epsilon: 0.310
# Episode 391/500, Reward: 17.0, Epsilon: 0.309
# Episode 392/500, Reward: 129.0, Epsilon: 0.308
# Episode 393/500, Reward: 9.0, Epsilon: 0.307
# Episode 394/500, Reward: 25.0, Epsilon: 0.306
# Episode 395/500, Reward: 89.0, Epsilon: 0.305
# Episode 396/500, Reward: 11.0, Epsilon: 0.304
# Episode 397/500, Reward: 19.0, Epsilon: 0.303
# Episode 398/500, Reward: 15.0, Epsilon: 0.302
# Episode 399/500, Reward: 11.0, Epsilon: 0.302
# Episode 400/500, Reward: 72.0, Epsilon: 0.301
# Episode 401/500, Reward: 12.0, Epsilon: 0.300
# Episode 402/500, Reward: 13.0, Epsilon: 0.299
# Episode 403/500, Reward: 101.0, Epsilon: 0.298
# Episode 404/500, Reward: 24.0, Epsilon: 0.297
# Episode 405/500, Reward: 109.0, Epsilon: 0.296
# Episode 406/500, Reward: 51.0, Epsilon: 0.295
# Episode 407/500, Reward: 21.0, Epsilon: 0.294
# Episode 408/500, Reward: 91.0, Epsilon: 0.294
# Episode 409/500, Reward: 15.0, Epsilon: 0.293
# Episode 410/500, Reward: 32.0, Epsilon: 0.292
# Episode 411/500, Reward: 21.0, Epsilon: 0.291
# Episode 412/500, Reward: 109.0, Epsilon: 0.290
# Episode 413/500, Reward: 96.0, Epsilon: 0.289
# Episode 414/500, Reward: 18.0, Epsilon: 0.288
# Episode 415/500, Reward: 61.0, Epsilon: 0.287
# Episode 416/500, Reward: 19.0, Epsilon: 0.287
# Episode 417/500, Reward: 108.0, Epsilon: 0.286
# Episode 418/500, Reward: 18.0, Epsilon: 0.285
# Episode 419/500, Reward: 15.0, Epsilon: 0.284
# Episode 420/500, Reward: 98.0, Epsilon: 0.283
# Episode 421/500, Reward: 21.0, Epsilon: 0.282
# Episode 422/500, Reward: 14.0, Epsilon: 0.281
# Episode 423/500, Reward: 83.0, Epsilon: 0.281
# Episode 424/500, Reward: 18.0, Epsilon: 0.280
# Episode 425/500, Reward: 84.0, Epsilon: 0.279
# Episode 426/500, Reward: 105.0, Epsilon: 0.278
# Episode 427/500, Reward: 106.0, Epsilon: 0.277
# Episode 428/500, Reward: 73.0, Epsilon: 0.276
# Episode 429/500, Reward: 35.0, Epsilon: 0.276
# Episode 430/500, Reward: 95.0, Epsilon: 0.275
# Episode 431/500, Reward: 97.0, Epsilon: 0.274
# Episode 432/500, Reward: 15.0, Epsilon: 0.273
# Episode 433/500, Reward: 67.0, Epsilon: 0.272
# Episode 434/500, Reward: 100.0, Epsilon: 0.271
# Episode 435/500, Reward: 91.0, Epsilon: 0.271
# Episode 436/500, Reward: 99.0, Epsilon: 0.270
# Episode 437/500, Reward: 94.0, Epsilon: 0.269
# Episode 438/500, Reward: 121.0, Epsilon: 0.268
# Episode 439/500, Reward: 22.0, Epsilon: 0.267
# Episode 440/500, Reward: 79.0, Epsilon: 0.267
# Episode 441/500, Reward: 106.0, Epsilon: 0.266
# Episode 442/500, Reward: 42.0, Epsilon: 0.265
# Episode 443/500, Reward: 109.0, Epsilon: 0.264
# Episode 444/500, Reward: 109.0, Epsilon: 0.263
# Episode 445/500, Reward: 126.0, Epsilon: 0.263
# Episode 446/500, Reward: 103.0, Epsilon: 0.262
# Episode 447/500, Reward: 74.0, Epsilon: 0.261
# Episode 448/500, Reward: 19.0, Epsilon: 0.260
# Episode 449/500, Reward: 113.0, Epsilon: 0.259
# Episode 450/500, Reward: 96.0, Epsilon: 0.259
# Episode 451/500, Reward: 121.0, Epsilon: 0.258
# Episode 452/500, Reward: 70.0, Epsilon: 0.257
# Episode 453/500, Reward: 130.0, Epsilon: 0.256
# Episode 454/500, Reward: 122.0, Epsilon: 0.256
# Episode 455/500, Reward: 110.0, Epsilon: 0.255
# Episode 456/500, Reward: 117.0, Epsilon: 0.254
# Episode 457/500, Reward: 105.0, Epsilon: 0.253
# Episode 458/500, Reward: 134.0, Epsilon: 0.253
# Episode 459/500, Reward: 118.0, Epsilon: 0.252
# Episode 460/500, Reward: 127.0, Epsilon: 0.251
# Episode 461/500, Reward: 41.0, Epsilon: 0.250
# Episode 462/500, Reward: 372.0, Epsilon: 0.250
# Episode 463/500, Reward: 41.0, Epsilon: 0.249
# Episode 464/500, Reward: 112.0, Epsilon: 0.248
# Episode 465/500, Reward: 172.0, Epsilon: 0.247
# Episode 466/500, Reward: 121.0, Epsilon: 0.247
# Episode 467/500, Reward: 129.0, Epsilon: 0.246
# Episode 468/500, Reward: 155.0, Epsilon: 0.245
# Episode 469/500, Reward: 123.0, Epsilon: 0.244
# Episode 470/500, Reward: 100.0, Epsilon: 0.244
# Episode 471/500, Reward: 19.0, Epsilon: 0.243
# Episode 472/500, Reward: 20.0, Epsilon: 0.242
# Episode 473/500, Reward: 107.0, Epsilon: 0.241
# Episode 474/500, Reward: 127.0, Epsilon: 0.241
# Episode 475/500, Reward: 311.0, Epsilon: 0.240
# Episode 476/500, Reward: 276.0, Epsilon: 0.239
# Episode 477/500, Reward: 80.0, Epsilon: 0.239
# Episode 478/500, Reward: 275.0, Epsilon: 0.238
# Episode 479/500, Reward: 41.0, Epsilon: 0.237
# Episode 480/500, Reward: 272.0, Epsilon: 0.236
# Episode 481/500, Reward: 269.0, Epsilon: 0.236
# Episode 482/500, Reward: 122.0, Epsilon: 0.235
# Episode 483/500, Reward: 271.0, Epsilon: 0.234
# Episode 484/500, Reward: 148.0, Epsilon: 0.234
# Episode 485/500, Reward: 65.0, Epsilon: 0.233
# Episode 486/500, Reward: 138.0, Epsilon: 0.232
# Episode 487/500, Reward: 124.0, Epsilon: 0.231
# Episode 488/500, Reward: 114.0, Epsilon: 0.231
# Episode 489/500, Reward: 290.0, Epsilon: 0.230
# Episode 490/500, Reward: 41.0, Epsilon: 0.229
# Episode 491/500, Reward: 247.0, Epsilon: 0.229
# Episode 492/500, Reward: 178.0, Epsilon: 0.228
# Episode 493/500, Reward: 118.0, Epsilon: 0.227
# Episode 494/500, Reward: 74.0, Epsilon: 0.227
# Episode 495/500, Reward: 286.0, Epsilon: 0.226
# Episode 496/500, Reward: 303.0, Epsilon: 0.225
# Episode 497/500, Reward: 103.0, Epsilon: 0.225
# Episode 498/500, Reward: 93.0, Epsilon: 0.224
# Episode 499/500, Reward: 275.0, Epsilon: 0.223
# Episode 500/500, Reward: 244.0, Epsilon: 0.223
# Figure(1000x500)
# Figure(1000x500)

# %% [markdown]
# ### Оценка работы обученного агента
#
# Посмотрим на графики обучения:
# - Тонкая линия - награды за эпизод, но поскольку эпизоды во многом случайны, эти данные довольно шумные
# - Толстая линия - Скользящее среднее (Running Mean) наград за эпизод, для фильтрации шумов
#
# Мы можем видеть, что несмотря на то что обучение нестабильно (это нормально для DQN), средняя награда все же растет

# %%
image_path = 'RL_course_2/training_DQN_RunMean.png'
try:
    display(Image(filename=image_path, width=1000))
except FileNotFoundError:
    print(f"Ошибка: Файл изображения '{image_path}' не найден.")

# %% [markdown]
# Посмотрим, как работает наш DQN-агент:

# %%
# !cd /content/RL_course_2/ && python run_catpole_DQN.py

gif_path = 'RL_course_2/cartpole_test_DQN.gif'
try:
    display(Image(filename=gif_path, width=500))
except FileNotFoundError:
    print(f"Ошибка: Файл GIF '{gif_path}' не найден.")
# Out:
# Модель загружена
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Оценка эпизода 1: Награда = 500.0
# Оценка эпизода 2: Награда = 500.0
# Оценка эпизода 3: Награда = 500.0
# Оценка эпизода 4: Награда = 500.0
# Оценка эпизода 5: Награда = 500.0
# Оценка эпизода 6: Награда = 500.0
# Traceback (most recent call last):
#   File "/content/RL_course_2/run_catpole_DQN.py", line 63, in <module>
#     img = env.render()
#           ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gymnasium/core.py", line 337, in render
#     return self.env.render()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/common.py", line 409, in render
#     return super().render()
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gymnasium/core.py", line 337, in render
#     return self.env.render()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/common.py", line 303, in render
#     return self.env.render()
#            ^^^^^^^^^^^^^^^^^
#   File "/content/RL_course_2/gymnasium_env_RL_course/envs/cartpole_env.py", line 106, in render
#     return self._render_rgb_array()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/RL_course_2/gymnasium_env_RL_course/envs/cartpole_env.py", line 119, in _render_rgb_array
#     ax.clear()
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py", line 1416, in clear
#     self.__clear()
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py", line 1294, in __clear
#     axis.clear()  # Also resets the scale to linear.
#     ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 892, in clear
#     self.reset_ticks()
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 915, in reset_ticks
#     self.set_clip_path(self.axes.patch)
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 1128, in set_clip_path
#     for child in self.majorTicks + self.minorTicks:
#                                    ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 552, in __get__
#     tick = instance._get_tick(major=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 1603, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 429, in __init__
#     super().__init__(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/axis.py", line 88, in __init__
#     super().__init__()
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/artist.py", line 200, in __init__
#     self._callbacks = cbook.CallbackRegistry(signals=["pchanged"])
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py", line 259, in __init__
#     def __init__(self, exception_handler=_exception_printer, *, signals=None):
#
# KeyboardInterrupt
# ^C

# %% [markdown]
# ### Не стесняйтесь пробовать менять среду и гиперпараметры для получения разных результатов, этот ноутбук создан именно для этого!

# %% [markdown]
# Например, можно изменить начальное положение в среде, вынуждая агента сначала перебросить маятник в вертикальное положение, а уже потом его удерживать (конечно, для этого надо изменить условия завершения эпизода и многое другое)
#
# Интересный пример решения этой проблемы в железе:
# [DQN обратный маятник с переворотом](https://www.youtube.com/watch?v=XMn1FI9_f8k)
